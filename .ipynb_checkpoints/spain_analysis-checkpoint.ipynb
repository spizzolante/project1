# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path = 'data/raw/WorldCupMatches.csv'

wcm_df = pd.read_csv(file_path)

# %%
# function to make all column names to lowercase
def update_columns_to_lower(df):
    df.columns = df.columns.str.lower().str.strip()
    return df


# function to convert all floats as integers
def float_to_int(df):
    for column in df.columns:
        if df[column].dtype == 'float64':
            df[column] = df[column].astype(int)
    return df

# %%
cleaned_df = wcm_df.dropna(thresh=3)

# %%
attendance_mean = wcm_df['Attendance'].mean()

# %%
cleaned_df['Attendance'] = cleaned_df['Attendance'].fillna(attendance_mean)
# Out:
# /tmp/ipykernel_44664/1476385943.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['Attendance'] = cleaned_df['Attendance'].fillna(attendance_mean)

# %%
cleaned_df = float_to_int(cleaned_df)
# Out:
# /tmp/ipykernel_44664/3882775948.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(int)
# /tmp/ipykernel_44664/3882775948.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(int)
# /tmp/ipykernel_44664/3882775948.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(int)
# /tmp/ipykernel_44664/3882775948.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(int)
# /tmp/ipykernel_44664/3882775948.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(int)
# /tmp/ipykernel_44664/3882775948.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(int)
# /tmp/ipykernel_44664/3882775948.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(int)
# /tmp/ipykernel_44664/3882775948.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(int)

# %%
cleaned_df = update_columns_to_lower(cleaned_df)

# %%
# Filter matches involving Spain
spain_matches = cleaned_df[(cleaned_df['home team name'] == 'Spain') | (cleaned_df['away team name'] == 'Spain')]

# %%
sns.set(style="whitegrid")

# %%
folder_path = "data/cleaned/"
spain_matches.to_csv(folder_path + 'spain_matches.csv')

# %%
# Initialize variables to track streaks
current_winning_streak = 0
max_winning_streak = 0
current_losing_streak = 0
max_losing_streak = 0

# Iterate through the DataFrame
for index, match in spain_matches.iterrows():
    if match['home team name'] == 'Spain' or match['away team name'] == 'Spain':
        # Check if Spain won the match
        if (match['home team name'] == 'Spain' and match['home team goals'] > match['away team goals']) or (match['away team name'] == 'Spain' and match['away team goals'] > match['home team goals']):
            current_winning_streak += 1
            # Update max winning streak if current streak is greater
            if current_winning_streak > max_winning_streak:
                max_winning_streak = current_winning_streak
            # Reset losing streak
            current_losing_streak = 0
        # Check if Spain lost the match
        else:
            current_losing_streak += 1
            # Update max losing streak if current streak is greater
            if current_losing_streak > max_losing_streak:
                max_losing_streak = current_losing_streak
            # Reset winning streak
            current_winning_streak = 0

print("Spain's best winning streak:", max_winning_streak)
print("Spain's worst losing streak:", max_losing_streak)
# Out:
# Spain's best winning streak: 6
# Spain's worst losing streak: 4

# %%
display(spain_matches)
# Out:
#      year               datetime              stage  \
# 23   1934   27 May 1934 - 16:30   Preliminary round
# 28   1934   31 May 1934 - 16:30      Quarter-finals
# 30   1934   01 Jun 1934 - 16:30      Quarter-finals
# 55   1950   25 Jun 1950 - 15:00             Group 2
# 60   1950   29 Jun 1950 - 15:00             Group 2
# 64   1950   02 Jul 1950 - 15:00             Group 2
# 69   1950   09 Jul 1950 - 15:00             Group 6
# 71   1950   13 Jul 1950 - 15:00             Group 6
# 73   1950   16 Jul 1950 - 15:00             Group 6
# 141  1962   31 May 1962 - 15:00             Group 3
# 149  1962   03 Jun 1962 - 15:00             Group 3
# 153  1962   06 Jun 1962 - 15:00             Group 3
# 174  1966   13 Jul 1966 - 19:30             Group 2
# 177  1966   15 Jul 1966 - 19:30             Group 2
# 190  1966   20 Jul 1966 - 19:30             Group 2
# 275  1978   03 Jun 1978 - 13:45             Group 3
# 282  1978   07 Jun 1978 - 13:45             Group 3
# 291  1978   11 Jun 1978 - 13:45             Group 3
# 316  1982   16 Jun 1982 - 21:00             Group 5
# 328  1982   20 Jun 1982 - 21:00             Group 5
# 343  1982   25 Jun 1982 - 21:00             Group 5
# 351  1982   02 Jul 1982 - 21:00             Group 2
# 355  1982   05 Jul 1982 - 21:00             Group 2
# 362  1986   01 Jun 1986 - 12:00             Group D
# 378  1986   07 Jun 1986 - 12:00             Group D
# 393  1986   12 Jun 1986 - 12:00             Group D
# 403  1986   18 Jun 1986 - 16:00         Round of 16
# 406  1986   22 Jun 1986 - 16:00      Quarter-finals
# 423  1990   13 Jun 1990 - 17:00             Group E
# 434  1990   17 Jun 1990 - 21:00             Group E
# 445  1990   21 Jun 1990 - 17:00             Group E
# 454  1990   26 Jun 1990 - 17:00         Round of 16
# 464  1994   17 Jun 1994 - 19:30             Group C
# 476  1994   21 Jun 1994 - 16:00             Group C
# 491  1994   27 Jun 1994 - 16:00             Group C
# 501  1994   02 Jul 1994 - 16:30         Round of 16
# 508  1994   09 Jul 1994 - 12:00      Quarter-finals
# 523  1998   13 Jun 1998 - 14:30             Group D
# 539  1998   19 Jun 1998 - 21:00             Group D
# 554  1998   24 Jun 1998 - 21:00             Group D
# 587  2002   02 Jun 2002 - 20:30             Group B
# 602  2002  07 June 2002 - 18:00             Group B
# 619  2002   12 Jun 2002 - 20:30             Group B
# 630  2002   16 Jun 2002 - 20:30         Round of 16
# 639  2002   22 Jun 2002 - 15:30      Quarter-finals
# 658  2006   14 Jun 2006 - 15:00             Group H
# 675  2006   19 Jun 2006 - 21:00             Group H
# 689  2006   23 Jun 2006 - 16:00             Group H
# 699  2006   27 Jun 2006 - 21:00         Round of 16
# 723  2010   16 Jun 2010 - 16:00             Group H
# 739  2010   21 Jun 2010 - 20:30             Group H
# 754  2010   25 Jun 2010 - 20:30             Group H
# 763  2010   29 Jun 2010 - 20:30         Round of 16
# 767  2010   03 Jul 2010 - 20:30      Quarter-finals
# 769  2010   07 Jul 2010 - 20:30         Semi-finals
# 771  2010   11 Jul 2010 - 20:30               Final
# 774  2014   13 Jun 2014 - 16:00             Group B
# 790  2014   18 Jun 2014 - 16:00             Group B
# 804  2014   23 Jun 2014 - 13:00             Group B
#
#                                        stadium               city  \
# 23                              Luigi Ferraris             Genoa
# 28                              Giovanni Berta          Florence
# 30                              Giovanni Berta          Florence
# 55                            Durival de Brito          Curitiba
# 60   Maracan� - Est�dio Jornalista M�rio Filho    Rio De Janeiro
# 64   Maracan� - Est�dio Jornalista M�rio Filho    Rio De Janeiro
# 69                                    Pacaembu         Sao Paulo
# 71   Maracan� - Est�dio Jornalista M�rio Filho    Rio De Janeiro
# 73                                    Pacaembu         Sao Paulo
# 141                          Estadio Sausalito      Vina Del Mar
# 149                          Estadio Sausalito      Vina Del Mar
# 153                          Estadio Sausalito      Vina Del Mar
# 174                                 Villa Park        Birmingham
# 177                               Hillsborough         Sheffield
# 190                                 Villa Park        Birmingham
# 275                            Jose Amalfitani      Buenos Aires
# 282                 Estadio Jos� Mar�a Minella     Mar Del Plata
# 291                            Jose Amalfitani      Buenos Aires
# 316                              Luis Casanova          Valencia
# 328                              Luis Casanova          Valencia
# 343                              Luis Casanova          Valencia
# 351                          Santiago Bernabeu            Madrid
# 355                          Santiago Bernabeu            Madrid
# 362                                    Jalisco       Guadalajara
# 378                              Tres de Marzo       Guadalajara
# 393                                Tecnologico         Monterrey
# 403                        Estadio Corregidora         Queretaro
# 406                                 Cuauhtemoc            Puebla
# 423                                Dacia Arena             Udine
# 434                                Dacia Arena             Udine
# 445                     Marc Antonio Bentegodi            Verona
# 454                     Marc Antonio Bentegodi            Verona
# 464                                Cotton Bowl            Dallas
# 476                              Soldier Field           Chicago
# 491                              Soldier Field           Chicago
# 501                                RFK Stadium     Washington Dc
# 508                            Foxboro Stadium            Boston
# 523                               La Beaujoire            Nantes
# 539                    Stade Geoffroy Guichard     Saint-Etienne
# 554                       Stade Felix Bollaert              Lens
# 587                  Gwangju World Cup Stadium           Gwangju
# 602                   Jeonju World Cup Stadium            Jeonju
# 619                  Daejeon World Cup Stadium           Daejeon
# 630                    Suwon World Cup Stadium             Suwon
# 639                  Gwangju World Cup Stadium           Gwangju
# 658                             Zentralstadion           Leipzig
# 675                   Gottlieb-Daimler-Stadion         Stuttgart
# 689                       Fritz-Walter-Stadion    Kaiserslautern
# 699            FIFA World Cup Stadium, Hanover           Hanover
# 723                             Durban Stadium            Durban
# 739                         Ellis Park Stadium      Johannesburg
# 754                    Loftus Versfeld Stadium  Tshwane/Pretoria
# 763                          Cape Town Stadium         Cape Town
# 767                         Ellis Park Stadium      Johannesburg
# 769                             Durban Stadium            Durban
# 771                        Soccer City Stadium      Johannesburg
# 774                           Arena Fonte Nova          Salvador
# 790                        Estadio do Maracana    Rio De Janeiro
# 804                           Arena da Baixada          Curitiba
#
#        home team name  home team goals  away team goals  \
# 23              Spain                3                1
# 28              Italy                1                1
# 30              Italy                1                0
# 55              Spain                3                1
# 60              Spain                2                0
# 64              Spain                1                0
# 69            Uruguay                2                2
# 71             Brazil                6                1
# 73             Sweden                3                1
# 141    Czechoslovakia                1                0
# 149             Spain                1                0
# 153            Brazil                2                1
# 174         Argentina                2                1
# 177             Spain                2                1
# 190        Germany FR                2                1
# 275           Austria                2                1
# 282            Brazil                0                0
# 291             Spain                1                0
# 316             Spain                1                1
# 328             Spain                2                1
# 343  Northern Ireland                1                0
# 351        Germany FR                2                1
# 355             Spain                0                0
# 362             Spain                0                1
# 378  Northern Ireland                1                2
# 393           Algeria                0                3
# 403           Denmark                1                5
# 406             Spain                1                1
# 423           Uruguay                0                0
# 434    Korea Republic                1                3
# 445           Belgium                1                2
# 454             Spain                1                2
# 464             Spain                2                2
# 476           Germany                1                1
# 491           Bolivia                1                3
# 501             Spain                3                0
# 508             Italy                2                1
# 523             Spain                2                3
# 539             Spain                0                0
# 554             Spain                6                1
# 587             Spain                3                1
# 602             Spain                3                1
# 619      South Africa                2                3
# 630             Spain                1                1
# 639             Spain                0                0
# 658             Spain                4                0
# 675             Spain                3                1
# 689      Saudi Arabia                0                1
# 699             Spain                1                3
# 723             Spain                0                1
# 739             Spain                2                0
# 754             Chile                1                2
# 763             Spain                1                0
# 767          Paraguay                0                1
# 769           Germany                0                1
# 771       Netherlands                0                1
# 774             Spain                1                5
# 790             Spain                0                2
# 804         Australia                0                3
#
#               away team name                            win conditions  \
# 23                    Brazil
# 28                     Spain
# 30                     Spain
# 55                       USA
# 60                     Chile
# 64                   England
# 69                     Spain
# 71                     Spain
# 73                     Spain
# 141                    Spain
# 149                   Mexico
# 153                    Spain
# 174                    Spain
# 177              Switzerland
# 190                    Spain
# 275                    Spain
# 282                    Spain
# 291                   Sweden
# 316                 Honduras
# 328               Yugoslavia
# 343                    Spain
# 351                    Spain
# 355                  England
# 362                   Brazil
# 378                    Spain
# 393                    Spain
# 403                    Spain
# 406                  Belgium         Belgium win on penalties (4 - 5)
# 423                    Spain
# 434                    Spain
# 445                    Spain
# 454               Yugoslavia          Yugoslavia win after extra time
# 464           Korea Republic
# 476                    Spain
# 491                    Spain
# 501              Switzerland
# 508                    Spain
# 523                  Nigeria
# 539                 Paraguay
# 554                 Bulgaria
# 587                 Slovenia
# 602                 Paraguay
# 619                    Spain
# 630  rn">Republic of Ireland           Spain win on penalties (3 - 2)
# 639           Korea Republic  Korea Republic win on penalties (3 - 5)
# 658                  Ukraine
# 675                  Tunisia
# 689                    Spain
# 699                   France
# 723              Switzerland
# 739                 Honduras
# 754                    Spain
# 763                 Portugal
# 767                    Spain
# 769                    Spain
# 771                    Spain               Spain win after extra time
# 774              Netherlands
# 790                    Chile
# 804                    Spain
#
#      attendance  half-time home goals  half-time away goals  \
# 23        21000                     3                     0
# 28        35000                     0                     0
# 30        43000                     1                     0
# 55         9511                     0                     1
# 60        19790                     2                     0
# 64        74462                     0                     0
# 69        44802                     1                     2
# 71       152772                     3                     0
# 73        11227                     2                     0
# 141       12700                     0                     0
# 149       11875                     0                     0
# 153       18715                     0                     1
# 174       42738                     0                     0
# 177       32028                     0                     1
# 190       42187                     1                     1
# 275       40841                     1                     1
# 282       34771                     0                     0
# 291       42132                     0                     0
# 316       49562                     0                     1
# 328       48000                     1                     1
# 343       49562                     0                     0
# 351       90089                     0                     0
# 355       75000                     0                     0
# 362       35748                     0                     0
# 378       28000                     0                     2
# 393       23980                     0                     1
# 403       38500                     1                     1
# 406       45000                     0                     0
# 423       35713                     0                     0
# 434       32733                     1                     1
# 445       35950                     1                     2
# 454       35500                     0                     0
# 464       56247                     0                     0
# 476       63113                     0                     1
# 491       63089                     0                     1
# 501       53121                     1                     0
# 508       53400                     1                     0
# 523       35500                     1                     1
# 539       30600                     0                     0
# 554       38100                     2                     0
# 587       28598                     1                     0
# 602       24000                     0                     1
# 619       31024                     1                     2
# 630       38926                     0                     0
# 639       42114                     0                     0
# 658       43000                     2                     0
# 675       52000                     0                     1
# 689       46000                     0                     1
# 699       43000                     1                     1
# 723       62453                     0                     0
# 739       54386                     1                     0
# 754       41958                     0                     2
# 763       62955                     0                     0
# 767       55359                     0                     0
# 769       60960                     0                     0
# 771       84490                     0                     0
# 774       48173                     1                     1
# 790       74101                     0                     2
# 804       39375                     0                     1
#
#                             referee                         assistant 1  \
# 23              BIRLEM Alfred (GER)              CARMINATI Ettore (ITA)
# 28                BAERT Louis (BEL)               ZENISEK Bohumil (TCH)
# 30                MERCET Rene (SUI)              IVANCSICS Mihaly (HUN)
# 55                VIANA Mario (BRA)          DA COSTA VIEIRA Jose (POR)
# 60            MALCHER Alberto (BRA)                MARINO Esteban (URU)
# 64           GALEATI Giovanni (ITA)                     LUTZ Jean (SUI)
# 69         GRIFFITHS Benjamin (WAL)              DATTILO Generoso (ITA)
# 71             LEAFE Reginald (ENG)               MITCHELL George (SCO)
# 73         VAN DER MEER Karel (NED)                     LUTZ Jean (SUI)
# 141              STEINER Carl (AUT)                MARINO Esteban (URU)
# 149            TESANIC Branko (YUG)                VICUNA Claudio (CHI)
# 153         BUSTAMANTE Sergio (CHI)                MARINO Esteban (URU)
# 174        RUMENTCHEV Dimitar (BUL)     YAMASAKI MALDONADO Arturo (MEX)
# 177           BAKHRAMOV Tofik (URS)                  ZSOLT Istvan (HUN)
# 190           MARQUES Armando (BRA)                VICUNA Claudio (CHI)
# 275            PALOTAI Karoly (HUN)            BARRETO RUIZ Ramon (URU)
# 282            GONELLA Sergio (ITA)                 KLEIN Abraham (ISR)
# 291         BIWERSI Ferdinand (GER)      ITHURRALDE Arturo Andres (ARG)
# 316  ITHURRALDE Arturo Andres (ARG)                DOTCHEV Bogdan (BUL)
# 328     LUND-SORENSEN Henning (DEN)               GARRIDO Antonio (POR)
# 343              ORTIZ Hector (PAR)         LABO REVOREDO Enrique (PER)
# 351             CASARIN Paolo (ITA)                 WOEHRER Franz (AUT)
# 355             PONNET Alexis (BEL)                VAUTROT Michel (FRA)
# 362     BAMBRIDGE Christopher (AUS)                   SOCHA David (USA)
# 378           BRUMMEIER Horst (AUT)                 AGNOLIN Luigi (ITA)
# 393             TAKADA Shizuo (JPN)            PICON-ACKONG Edwin (MRI)
# 403                KEIZER Jan (NED)                 BENNACEUR Ali (TUN)
# 406        KIRSCHEN Siegfried (GER)        CODESAL MENDEZ Edgardo (MEX)
# 423               KOHL Helmut (AUT)                 SPIRIN Alexey (RUS)
# 434  JACOME GUERRERO Elias V. (ECU)               MAGNI Pierluigi (ITA)
# 445              LOUSTAU Juan (ARG)                 MACIEL Carlos (PAR)
# 454          SCHMIDHUBER Aron (GER)                   SNODDY Alan (NIR)
# 464           MIKKELSEN Peter (DEN)  CHRISTENSEN Carl-Johan Meyer (DEN)
# 476           FILIPPI Ernesto (URU)               ZARATE Venancio (PAR)
# 491           BADILLA Rodrigo (CRC)         CALIX GARCIA Raimundo (HON)
# 501        VAN DER ENDE Mario (NED)                   DOLSTRA Jan (NED)
# 508               PUHL Sandor (HUN)                DUNSTER Gordon (AUS)
# 523            BAHARMAST Esse (USA)            TORRES ZUNIGA Luis (CRC)
# 539                McLEOD Ian (RSA)      SOLDATOS Aristidis Chris (RSA)
# 554        VAN DER ENDE Mario (NED)            GRIGORESCU Nicolae (ROU)
# 587          GUEZZAZ Mohammed (MAR)                 TOMUSANGE Ali (UGA)
# 602         EL GHANDOUR Gamal (EGY)                   FARAG Wagih (EGY)
# 619                 MANE Saad (KUW)               RATTALINO Jorge (ARG)
# 630              FRISK Anders (SWE)                 LINDBERG Leif (SWE)
# 639         EL GHANDOUR Gamal (EGY)                 TOMUSANGE Ali (UGA)
# 658           BUSACCA Massimo (SUI)            BURAGINA Francesco (SUI)
# 675              SIMON Carlos (BRA)               TAVARES Aristeu (BRA)
# 689              CODJIA Coffi (BEN)           NTAGUNGIRA Celestin (RWA)
# 699           ROSETTI Roberto (ITA)             COPELLI Cristiano (ITA)
# 723               WEBB Howard (ENG)                   Darren CANN (ENG)
# 739          NISHIMURA Yuichi (JPN)                   SAGARA Toru (JPN)
# 754           RODRIGUEZ Marco (MEX)             CAMARGO Jose Luis (MEX)
# 763           BALDASSI Hector (ARG)                 CASAS Ricardo (ARG)
# 767             BATRES Carlos (GUA)                   LEAL Leonel (CRC)
# 769             KASSAI Viktor (HUN)                    EROS Gabor (HUN)
# 771               WEBB Howard (ENG)                   Darren CANN (ENG)
# 774            Nicola RIZZOLI (ITA)               Renato FAVERANI (ITA)
# 790               GEIGER Mark (USA)                     HURD Sean (USA)
# 804           SHUKRALLA Nawaf (BHR)                 TULEFAT Yaser (BHR)
#
#                          assistant 2   roundid    matchid home team initials  \
# 23            IVANCSICS Mihaly (HUN)       204       1111                ESP
# 28            IVANCSICS Mihaly (HUN)       418       1122                ITA
# 30             ZENISEK Bohumil (TCH)       418       1123                ITA
# 55         DE LA SALLE Charles (FRA)       208       1208                ESP
# 60             ALVAREZ Alfredo (BOL)       208       1193                ESP
# 64            DATTILO Generoso (ITA)       208       1199                ESP
# 69             ALVAREZ Alfredo (BOL)       209       1207                URU
# 71        DA COSTA VIEIRA Jose (POR)       209       1186                BRA
# 73            GARCIA Prudencio (USA)       209       1206                SWE
# 141    VAN ROSBERG Walter Jose (CUW)       231       1498                TCH
# 149    VAN ROSBERG Walter Jose (CUW)       231       1497                ESP
# 153      SUNDHEIM Jose Antonio (COL)       231       1460                BRA
# 174         ZECEVIC Konstantin (YUG)       238       1578                ARG
# 177              PHILLIPS Hugh (SCO)       238       1641                ESP
# 190             CHOI Duk Ryong (PRK)       238       1637                FRG
# 275             IVANOV Anatoly (URS)       278       2216                AUT
# 282   ITHURRALDE Arturo Andres (ARG)       278       2246                BRA
# 291               PROKOP Adolf (GDR)       278       2337                ESP
# 316             BARRANCOS Luis (BOL)       293        901                ESP
# 328   ITHURRALDE Arturo Andres (ARG)       293        903                ESP
# 343              PONNET Alexis (BEL)       293        902                NIR
# 351             PALOTAI Karoly (HUN)       294        900                FRG
# 355             LACARNE Belaid (ALG)       294        877                ESP
# 362                 KEIZER Jan (NED)       308        439                ESP
# 378               NEMETH Lajos (HUN)       308        551                NIR
# 393            ESPOSITO Carlos (ARG)       308        378                ALG
# 403             DOTCHEV Bogdan (BUL)       309        511                DEN
# 406            BRUMMEIER Horst (AUT)       714        421                ESP
# 423         KIRSCHEN Siegfried (GER)       322        180                URU
# 434               LOUSTAU Juan (ARG)       322        175                KOR
# 445              MAURO Vincent (USA)       322         56                BEL
# 454         LISTKIEWICZ Michal (POL)       323        181                ESP
# 464                PEARSON Roy (ENG)       337       3050                ESP
# 476              TAIBI Ernesto (ARG)       337       3060                GER
# 491  AL GHATTAN Yousif Abdulla (BAH)       337       3075                BOL
# 501              MARTON Sandor (HUN)       338       3086                ESP
# 508                MATTHYS Luc (BEL)       796       3097                ITA
# 523               DUPANOV Yuri (BLR)      1014       8731                ESP
# 539                POWELL Owen (JAM)      1014       8748                ESP
# 554              ROSSI Claudio (ARG)      1014       8761                ESP
# 587              BEREUTER Egon (AUT)  43950100   43950008                ESP
# 602         MUDZAMIRI Brighton (ZIM)  43950100   43950022                ESP
# 619             HASSOUNEH Awni (JOR)  43950100   43950039                RSA
# 630                SRAMKA Igor (SVK)  43950200   43950052                ESP
# 639          RAGOONATH Michael (TRI)  43950300   43950059                ESP
# 658             ARNET Matthias (SUI)  97410100   97410015                ESP
# 675            CORONA Ednilson (BRA)  97410100   97410031                ESP
# 689          ADERODJOU Aboudou (BEN)  97410100   97410047                KSA
# 699        STAGNOLI Alessandro (ITA)  97410200   97410056                ESP
# 723          MULLARKEY Michael (ENG)    249722  300111112                ESP
# 739             JEONG Hae Sang (KOR)    249722  300061494                ESP
# 754              MORIN Alberto (MEX)    249722  300061491                CHI
# 763             MAIDANA Hernan (ARG)    249717  300061498                ESP
# 767            PASTRANA Carlos (HON)    249718  300061506                PAR
# 769                VAMOS Tibor (HUN)    249719  300111114                GER
# 771          MULLARKEY Michael (ENG)    249721  300061509                NED
# 774             Andrea STEFANI (ITA)    255931  300186510                ESP
# 790               FLETCHER Joe (CAN)    255931  300186498                ESP
# 804              SALEH Ebrahim (BHR)    255931  300186467                AUS
#
#     away team initials
# 23                 BRA
# 28                 ESP
# 30                 ESP
# 55                 USA
# 60                 CHI
# 64                 ENG
# 69                 ESP
# 71                 ESP
# 73                 ESP
# 141                ESP
# 149                MEX
# 153                ESP
# 174                ESP
# 177                SUI
# 190                ESP
# 275                ESP
# 282                ESP
# 291                SWE
# 316                HON
# 328                YUG
# 343                ESP
# 351                ESP
# 355                ENG
# 362                BRA
# 378                ESP
# 393                ESP
# 403                ESP
# 406                BEL
# 423                ESP
# 434                ESP
# 445                ESP
# 454                YUG
# 464                KOR
# 476                ESP
# 491                ESP
# 501                SUI
# 508                ESP
# 523                NGA
# 539                PAR
# 554                BUL
# 587                SVN
# 602                PAR
# 619                ESP
# 630                IRL
# 639                KOR
# 658                UKR
# 675                TUN
# 689                ESP
# 699                FRA
# 723                SUI
# 739                HON
# 754                ESP
# 763                POR
# 767                ESP
# 769                ESP
# 771                ESP
# 774                NED
# 790                CHI
# 804                ESP

# %%
spain_matches = spain_matches.drop(columns=['referee', 'assistant 1', 'assistant 2', 'roundid', 'matchid'])

# %%
spain_matches.tail(3)
# Out:
#      year              datetime    stage              stadium  \
# 774  2014  13 Jun 2014 - 16:00   Group B     Arena Fonte Nova
# 790  2014  18 Jun 2014 - 16:00   Group B  Estadio do Maracana
# 804  2014  23 Jun 2014 - 13:00   Group B     Arena da Baixada
#
#                 city home team name  home team goals  away team goals  \
# 774        Salvador           Spain                1                5
# 790  Rio De Janeiro           Spain                0                2
# 804        Curitiba       Australia                0                3
#
#     away team name win conditions  attendance  half-time home goals  \
# 774    Netherlands                      48173                     1
# 790          Chile                      74101                     0
# 804          Spain                      39375                     0
#
#      half-time away goals home team initials away team initials
# 774                     1                ESP                NED
# 790                     2                ESP                CHI
# 804                     1                AUS                ESP

# %%
spain_matches.shape
# Out:
# (59, 15)

# %%
spain_matches.reset_index(drop=True, inplace=True)

# %%
spain_matches_2018_1 = {
    'year' : 2018,
    'datetime' : '15 Jun 2018 - ',
    'stage' : 'Group B',
    'stadium' : 'Fisht Stadium',
    'city' : 'Sochi',
    'home team name' : 'Portugal',
    'home team goals' : 3,
    'away team goals' : 3,
    'away team name' : 'Spain',
    #'win conditions' : ,
    'attendance' : 43866,
    'half-time home goals' : 2,
    'half-time away goals' : 1,
    'home team initials' : 'POR',
    'away team initials' : 'ESP'
}

spain_matches_2018_2 = {
    'year' : 2018,
    'datetime' : '20 Jun 2018 - ',
    'stage' : 'Group B',
    'stadium' : 'Kazan Arena',
    'city' : 'Kazan',
    'home team name' : 'Iran',
    'home team goals' : 0,
    'away team goals' : 1,
    'away team name' : 'Spain',
    #'win conditions' : ,
    'attendance' : 42718,
    'half-time home goals' : 0,
    'half-time away goals' : 0,
    'home team initials' : 'IRN',
    'away team initials' : 'ESP'
}

spain_matches_2018_3 = {
    'year' : 2018,
    'datetime' : '25 Jun 2018 - ',
    'stage' : 'Group B',
    'stadium' : 'Kaliningrad Stadium',
    'city' : 'Kaliningrad',
    'home team name' : 'Spain',
    'home team goals' : 2,
    'away team goals' : 2,
    'away team name' : 'Morocco',
    #'win conditions' : ,
    'attendance' : 33973,
    'half-time home goals' : 1,
    'half-time away goals' : 1,
    'home team initials' : 'ESP',
    'away team initials' : 'MOR'
}

spain_matches_2018_4 = {
    'year' : 2018,
    'datetime' : '1 Jul 2018 - ',
    'stage' : 'Round of 16',
    'stadium' : 'Luzhniki Stadium',
    'city' : 'Moscow',
    'home team name' : 'Spain',
    'home team goals' : 1,
    'away team goals' : 1,
    'away team name' : 'Russia',
    'win conditions' : 'Russia win in penalties',
    'attendance' : 78011,
    'half-time home goals' : 1,
    'half-time away goals' : 1,
    'home team initials' : 'ESP',
    'away team initials' : 'RUS'
}

spain_matches_2022_1 = {
    'year' : 2022,
    'datetime' : '23 Nov 2022 - ',
    'stage' : 'Group E',
    'stadium' : 'Al Thumama Stadium',
    'city' : 'Doha',
    'home team name' : 'Spain',
    'home team goals' : 7,
    'away team goals' : 0,
    'away team name' : 'Costa Rica',
    #'win conditions' : ,
    'attendance' : 40013,
    'half-time home goals' : 3,
    'half-time away goals' : 0,
    'home team initials' : 'ESP',
    'away team initials' : 'CRC'
}

spain_matches_2022_2 = {
    'year' : 2022,
    'datetime' : '27 Nov 2022 - ',
    'stage' : 'Group E',
    'stadium' : 'Al Bayt Stadium',
    'city' : 'Al Khor',
    'home team name' : 'Spain',
    'home team goals' : 1,
    'away team goals' : 1,
    'away team name' : 'Germany',
    #'win conditions' : ,
    'attendance' : 68895,
    'half-time home goals' : 0,
    'half-time away goals' : 0,
    'home team initials' : 'ESP',
    'away team initials' : 'GER'
}

spain_matches_2022_3 = {
    'year' : 2022,
    'datetime' : '1 Dec 2022 - ',
    'stage' : 'Group E',
    'stadium' : 'Khalifa International Stadium',
    'city' : 'Al Rayyan',
    'home team name' : 'Japan',
    'home team goals' : 2,
    'away team goals' : 1,
    'away team name' : 'Spain',
    #'win conditions' : ,
    'attendance' : 44851,
    'half-time home goals' : 0,
    'half-time away goals' : 1,
    'home team initials' : 'JAP',
    'away team initials' : 'ESP'
}


spain_matches_2022_4 = {
    'year' : 2022,
    'datetime' : '6 Dec 2022 - ',
    'stage' : 'Round of 16',
    'stadium' : 'Education City Stadium',
    'city' : 'Al Rayyan',
    'home team name' : 'Morocco',
    'home team goals' : 0,
    'away team goals' : 0,
    'away team name' : 'Spain',
    'win conditions' : 'Morocco win after penalties',
    'attendance' : 44667,
    'half-time home goals' : 0,
    'half-time away goals' : 0,
    'home team initials' : 'MOR',
    'away team initials' : 'ESP',
}

# %%
df2018_1 = pd.DataFrame(spain_matches_2018_1, index=[59])

# %%
df2018_2 = pd.DataFrame(spain_matches_2018_2, index=[60])

# %%
df2018_3 = pd.DataFrame(spain_matches_2018_3, index=[61])

# %%
df2018_4 = pd.DataFrame(spain_matches_2018_4, index=[62])

# %%
df2022_1 = pd.DataFrame(spain_matches_2022_1, index=[63])

# %%
df2022_2 = pd.DataFrame(spain_matches_2022_2, index=[64])

# %%
df2022_3 = pd.DataFrame(spain_matches_2022_3, index=[65])

# %%
df2022_4 = pd.DataFrame(spain_matches_2022_4, index=[66])

# %%
# to append df2 at the end of df1 dataframe
#df1.append(df2)

# %%
spain_matches = pd.concat([spain_matches, df2018_1], ignore_index=True, verify_integrity=True)

# %%
spain_matches.shape
# Out:
# (60, 15)

# %%
spain_matches = pd.concat([spain_matches, df2018_2], ignore_index=True, verify_integrity=True)

# %%
spain_matches = pd.concat([spain_matches, df2018_3], ignore_index=True, verify_integrity=True)

# %%
spain_matches = pd.concat([spain_matches, df2018_4], ignore_index=True, verify_integrity=True)

# %%
spain_matches = pd.concat([spain_matches, df2022_1], ignore_index=True, verify_integrity=True)

# %%
spain_matches = pd.concat([spain_matches, df2022_2], ignore_index=True, verify_integrity=True)

# %%
spain_matches = pd.concat([spain_matches, df2022_3], ignore_index=True, verify_integrity=True)

# %%
spain_matches = pd.concat([spain_matches, df2022_4], ignore_index=True, verify_integrity=True)

# %%
spain_matches.shape
# Out:
# (67, 15)

# %%
display(spain_matches)
# Out:
#     year              datetime              stage  \
# 0   1934  27 May 1934 - 16:30   Preliminary round
# 1   1934  31 May 1934 - 16:30      Quarter-finals
# 2   1934  01 Jun 1934 - 16:30      Quarter-finals
# 3   1950  25 Jun 1950 - 15:00             Group 2
# 4   1950  29 Jun 1950 - 15:00             Group 2
# ..   ...                   ...                ...
# 62  2018         1 Jul 2018 -         Round of 16
# 63  2022        23 Nov 2022 -             Group E
# 64  2022        27 Nov 2022 -             Group E
# 65  2022         1 Dec 2022 -             Group E
# 66  2022         6 Dec 2022 -         Round of 16
#
#                                       stadium             city home team name  \
# 0                              Luigi Ferraris           Genoa           Spain
# 1                              Giovanni Berta        Florence           Italy
# 2                              Giovanni Berta        Florence           Italy
# 3                            Durival de Brito        Curitiba           Spain
# 4   Maracan� - Est�dio Jornalista M�rio Filho  Rio De Janeiro           Spain
# ..                                        ...              ...            ...
# 62                           Luzhniki Stadium           Moscow          Spain
# 63                         Al Thumama Stadium             Doha          Spain
# 64                            Al Bayt Stadium          Al Khor          Spain
# 65              Khalifa International Stadium        Al Rayyan          Japan
# 66                     Education City Stadium        Al Rayyan        Morocco
#
#     home team goals  away team goals away team name  \
# 0                 3                1         Brazil
# 1                 1                1          Spain
# 2                 1                0          Spain
# 3                 3                1            USA
# 4                 2                0          Chile
# ..              ...              ...            ...
# 62                1                1         Russia
# 63                7                0     Costa Rica
# 64                1                1        Germany
# 65                2                1          Spain
# 66                0                0          Spain
#
#                  win conditions  attendance  half-time home goals  \
# 0                                     21000                     3
# 1                                     35000                     0
# 2                                     43000                     1
# 3                                      9511                     0
# 4                                     19790                     2
# ..                          ...         ...                   ...
# 62      Russia win in penalties       78011                     1
# 63                          NaN       40013                     3
# 64                          NaN       68895                     0
# 65                          NaN       44851                     0
# 66  Morocco win after penalties       44667                     0
#
#     half-time away goals home team initials away team initials
# 0                      0                ESP                BRA
# 1                      0                ITA                ESP
# 2                      0                ITA                ESP
# 3                      1                ESP                USA
# 4                      0                ESP                CHI
# ..                   ...                ...                ...
# 62                     1                ESP                RUS
# 63                     0                ESP                CRC
# 64                     0                ESP                GER
# 65                     1                JAP                ESP
# 66                     0                MOR                ESP
#
# [67 rows x 15 columns]

# %%
win_conditions_mode = spain_matches['win conditions'].mode()[0]

# %%
print(win_conditions_mode)

# %%
spain_matches['win conditions'] = spain_matches['win conditions'].fillna(win_conditions_mode)

# %%
display(spain_matches)
# Out:
#     year              datetime              stage  \
# 0   1934  27 May 1934 - 16:30   Preliminary round
# 1   1934  31 May 1934 - 16:30      Quarter-finals
# 2   1934  01 Jun 1934 - 16:30      Quarter-finals
# 3   1950  25 Jun 1950 - 15:00             Group 2
# 4   1950  29 Jun 1950 - 15:00             Group 2
# ..   ...                   ...                ...
# 62  2018         1 Jul 2018 -         Round of 16
# 63  2022        23 Nov 2022 -             Group E
# 64  2022        27 Nov 2022 -             Group E
# 65  2022         1 Dec 2022 -             Group E
# 66  2022         6 Dec 2022 -         Round of 16
#
#                                       stadium             city home team name  \
# 0                              Luigi Ferraris           Genoa           Spain
# 1                              Giovanni Berta        Florence           Italy
# 2                              Giovanni Berta        Florence           Italy
# 3                            Durival de Brito        Curitiba           Spain
# 4   Maracan� - Est�dio Jornalista M�rio Filho  Rio De Janeiro           Spain
# ..                                        ...              ...            ...
# 62                           Luzhniki Stadium           Moscow          Spain
# 63                         Al Thumama Stadium             Doha          Spain
# 64                            Al Bayt Stadium          Al Khor          Spain
# 65              Khalifa International Stadium        Al Rayyan          Japan
# 66                     Education City Stadium        Al Rayyan        Morocco
#
#     home team goals  away team goals away team name  \
# 0                 3                1         Brazil
# 1                 1                1          Spain
# 2                 1                0          Spain
# 3                 3                1            USA
# 4                 2                0          Chile
# ..              ...              ...            ...
# 62                1                1         Russia
# 63                7                0     Costa Rica
# 64                1                1        Germany
# 65                2                1          Spain
# 66                0                0          Spain
#
#                  win conditions  attendance  half-time home goals  \
# 0                                     21000                     3
# 1                                     35000                     0
# 2                                     43000                     1
# 3                                      9511                     0
# 4                                     19790                     2
# ..                          ...         ...                   ...
# 62      Russia win in penalties       78011                     1
# 63                                    40013                     3
# 64                                    68895                     0
# 65                                    44851                     0
# 66  Morocco win after penalties       44667                     0
#
#     half-time away goals home team initials away team initials
# 0                      0                ESP                BRA
# 1                      0                ITA                ESP
# 2                      0                ITA                ESP
# 3                      1                ESP                USA
# 4                      0                ESP                CHI
# ..                   ...                ...                ...
# 62                     1                ESP                RUS
# 63                     0                ESP                CRC
# 64                     0                ESP                GER
# 65                     1                JAP                ESP
# 66                     0                MOR                ESP
#
# [67 rows x 15 columns]

# %%
folder_path = "data/cleaned/"
spain_matches.to_csv(folder_path + 'spain_matches.csv')

# %%
# For matches where Spain was the home team
spain_home_matches = spain_matches[spain_matches['home team name'] == 'Spain']
spain_home_goals_scored = spain_home_matches['home team goals'].sum()
spain_home_goals_conceded = spain_home_matches['away team goals'].sum()

# For matches where Spain was the away team
spain_away_matches = spain_matches[spain_matches['away team name'] == 'Spain']
spain_away_goals_scored = spain_away_matches['away team goals'].sum()
spain_away_goals_conceded = spain_away_matches['home team goals'].sum()

# %%
# Calculate total goals scored and conceded by Spain
total_goals_scored = spain_home_goals_scored + spain_away_goals_scored
total_goals_conceded = spain_home_goals_conceded + spain_away_goals_conceded

# Calculate Spain's goal differential
spain_goal_differential = total_goals_scored - total_goals_conceded

# %%
# Create a dataframe to store Spain's goal information
spain_goals_info = pd.DataFrame({
    'Team': ['Spain'],
    'Total Goals Scored': [total_goals_scored],
    'Total Goals Conceded': [total_goals_conceded],
    'Goal Differential': [spain_goal_differential]
})

# %%
spain_goals_info.head()
# Out:
#     Team  Total Goals Scored  Total Goals Conceded  Goal Differential
# 0  Spain                 108                    75                 33

# %%
# Filter matches where is spain is Home or is Away
spain_home_matches = cleaned_df[cleaned_df['home team name'] == 'Spain']
spain_away_matches = cleaned_df[cleaned_df['away team name'] == 'Spain']
#spain_matches = pd.concat([spain_home_matches, spain_away_matches])

# Calculate average goals scored and conceded when Spain is Home
avg_goals_scored_home = spain_home_matches['home team goals'].mean()
avg_goals_conceded_home = spain_home_matches['away team goals'].mean()

# Calculate average goals scored and conceded when Spain is Away
avg_goals_scored_away = spain_away_matches['away team goals'].mean()
avg_goals_conceded_away = spain_away_matches['home team goals'].mean()

# Calculate overall average goals scored and conceded
avg_goals_scored = (avg_goals_scored_home + avg_goals_scored_away) / 2
avg_goals_conceded = (avg_goals_conceded_home + avg_goals_conceded_away) / 2

print("Average goals scored by Spain per match:", avg_goals_scored)
print("Average goals conceded by Spain per match:", avg_goals_conceded)
# Out:
# Average goals scored by Spain per match: 1.5574712643678161
# Average goals conceded by Spain per match: 1.1206896551724137

# %%
# Opponents Spain has beaten the most
most_wins = spain_matches[spain_matches['home team name'] == 'Spain']['away team name'].value_counts()

# Opponents Spain has lost to the most
most_losses = spain_matches[spain_matches['away team name'] == 'Spain']['home team name'].value_counts()

# %%
# Calculate Win-Loss Record
spain_home_wins = len(spain_matches[(spain_matches['home team name'] == 'Spain') & (spain_matches['home team goals'] > spain_matches['away team goals'])])
spain_away_wins = len(spain_matches[(spain_matches['away team name'] == 'Spain') & (spain_matches['away team goals'] > spain_matches['home team goals'])])
spain_wins = spain_home_wins + spain_away_wins

spain_home_losses = len(spain_matches[(spain_matches['home team name'] == 'Spain') & (spain_matches['home team goals'] < spain_matches['away team goals'])])
spain_away_losses = len(spain_matches[(spain_matches['away team name'] == 'Spain') & (spain_matches['away team goals'] < spain_matches['home team goals'])])
spain_losses = spain_home_losses + spain_away_losses

print("Spain's win-loss record:")
print("Wins:", spain_wins)
print("Losses:", spain_losses)
# Out:
# Spain's win-loss record:
# Wins: 31
# Losses: 19

# %%
sns.barplot(x=['Average Goals Scored', 'Average Goals Conceded'], y=[avg_goals_scored, avg_goals_conceded])
# Out:
# <Axes: >

# %%
sns.barplot(x=['Wins', 'Losses'], y=[spain_wins, spain_losses])
# Out:
# <Axes: >

# %%
# Count occurrences of teams that Spain has beaten the most and lost to the most
most_wins_counts = spain_matches[spain_matches['home team name'] == 'Spain']['away team name'].value_counts().head(5)
most_losses_counts = spain_matches[spain_matches['away team name'] == 'Spain']['home team name'].value_counts().head(5)

# Create separate plots for most wins and most losses
fig, axs = plt.subplots(2, figsize=(10, 12))

# Plot most wins
most_wins_counts.plot(kind='bar', ax=axs[0], color='skyblue')
axs[0].set_title('Top 5 Teams Spain Has Beaten the Most')
axs[0].set_xlabel('Team')
axs[0].set_ylabel('Count')

# Plot most losses
most_losses_counts.plot(kind='bar', ax=axs[1], color='salmon')
axs[1].set_title('Top 5 Teams Spain Has Lost to the Most')
axs[1].set_xlabel('Team')
axs[1].set_ylabel('Count')

# Adjust layout
plt.tight_layout()

# Show plots
plt.show()

# %%
# Initialize variables to track streaks
current_winning_streak = 0
max_winning_streak = 0
current_losing_streak = 0
max_losing_streak = 0

# Iterate through the Dataframe
for index, match in spain_matches.iterrows():
    if match['home team name'] == 'Spain' or match['away team name'] == 'Spain':
        # Check if Spain won the match
        if (match['home team name'] == 'Spain' and match['home team goals'] > match['away team goals']) or (match['away team name'] == 'Spain' and match['away team goals'] > match['home team goals']):
            current_winning_streak += 1
            # Update max winning streak if current streak is greater
            if current_winning_streak > max_winning_streak:
                max_winning_streak = current_winning_streak
            # Reset losing streak
            current_losing_streak = 0
        # Check if Spain lost the match
        else:
            current_losing_streak += 1
            # Update max losing streak if current streak is greater
            if current_losing_streak > max_losing_streak:
                max_losing_streak = current_losing_streak
            # Reset winning streak
            current_winning_streak = 0

print("Spain's best winning streak:", max_winning_streak)
print("Spain's worst losing streak:", max_losing_streak)
# Out:
# Spain's best winning streak: 6
# Spain's worst losing streak: 4

# %%
spain_copy = spain_matches.copy()

# %%
spain_copy['stage reached'] = ''

# %%
spain_copy['stage']['year'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 spain_copy['stage']['year'].value_counts()
#
# File ~/Desktop/Ironhack/Week3/Project1/project1_env/lib/python3.11/site-packages/pandas/core/series.py:1112, in Series.__getitem__(self, key)
#    1109     return self._values[key]
#    1111 elif key_is_scalar:
# -> 1112     return self._get_value(key)
#    1114 # Convert generator to list before going through hashable part
#    1115 # (We will iterate through the generator there to check for slices)
#    1116 if is_iterator(key):
#
# File ~/Desktop/Ironhack/Week3/Project1/project1_env/lib/python3.11/site-packages/pandas/core/series.py:1228, in Series._get_value(self, label, takeable)
#    1225     return self._values[label]
#    1227 # Similar to Index.get_value, but we do not fall back to positional
# -> 1228 loc = self.index.get_loc(label)
#    1230 if is_integer(loc):
#    1231     return self._values[loc]
#
# File ~/Desktop/Ironhack/Week3/Project1/project1_env/lib/python3.11/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'year'

# %%
stage_mapping = {
    'Group B' : "Group Stage",
    'Group 2' : "Group Stage",
    'Group 3' : "Group Stage",
    'Group D' : "Group Stage",
    'Group E' : "Group Stage",
    'Group H' : "Group Stage",
    'Group 6' : "Group Stage",
    'Group 5' : "Group Stage",
    'Group C' : "Group Stage",
    'Round of 16' : "Round of 16",
    'Quarter-finals' : "Quarter-finals",
    'Preliminary round' : "Preliminary round",
    'Semi-finals' : "Semi-finals",
    'Final' : "Final"
}

# %%
spain_copy['stage reached'] = spain_copy['stage'].map(stage_mapping)

# %%
display(spain_copy)
# Out:
#     year              datetime              stage  \
# 0   1934  27 May 1934 - 16:30   Preliminary round
# 1   1934  31 May 1934 - 16:30      Quarter-finals
# 2   1934  01 Jun 1934 - 16:30      Quarter-finals
# 3   1950  25 Jun 1950 - 15:00             Group 2
# 4   1950  29 Jun 1950 - 15:00             Group 2
# ..   ...                   ...                ...
# 62  2018         1 Jul 2018 -         Round of 16
# 63  2022        23 Nov 2022 -             Group E
# 64  2022        27 Nov 2022 -             Group E
# 65  2022         1 Dec 2022 -             Group E
# 66  2022         6 Dec 2022 -         Round of 16
#
#                                       stadium             city home team name  \
# 0                              Luigi Ferraris           Genoa           Spain
# 1                              Giovanni Berta        Florence           Italy
# 2                              Giovanni Berta        Florence           Italy
# 3                            Durival de Brito        Curitiba           Spain
# 4   Maracan� - Est�dio Jornalista M�rio Filho  Rio De Janeiro           Spain
# ..                                        ...              ...            ...
# 62                           Luzhniki Stadium           Moscow          Spain
# 63                         Al Thumama Stadium             Doha          Spain
# 64                            Al Bayt Stadium          Al Khor          Spain
# 65              Khalifa International Stadium        Al Rayyan          Japan
# 66                     Education City Stadium        Al Rayyan        Morocco
#
#     home team goals  away team goals away team name  \
# 0                 3                1         Brazil
# 1                 1                1          Spain
# 2                 1                0          Spain
# 3                 3                1            USA
# 4                 2                0          Chile
# ..              ...              ...            ...
# 62                1                1         Russia
# 63                7                0     Costa Rica
# 64                1                1        Germany
# 65                2                1          Spain
# 66                0                0          Spain
#
#                  win conditions  attendance  half-time home goals  \
# 0                                     21000                     3
# 1                                     35000                     0
# 2                                     43000                     1
# 3                                      9511                     0
# 4                                     19790                     2
# ..                          ...         ...                   ...
# 62      Russia win in penalties       78011                     1
# 63                          NaN       40013                     3
# 64                          NaN       68895                     0
# 65                          NaN       44851                     0
# 66  Morocco win after penalties       44667                     0
#
#     half-time away goals home team initials away team initials  \
# 0                      0                ESP                BRA
# 1                      0                ITA                ESP
# 2                      0                ITA                ESP
# 3                      1                ESP                USA
# 4                      0                ESP                CHI
# ..                   ...                ...                ...
# 62                     1                ESP                RUS
# 63                     0                ESP                CRC
# 64                     0                ESP                GER
# 65                     1                JAP                ESP
# 66                     0                MOR                ESP
#
#         stage reached
# 0   Preliminary round
# 1      Quarter-finals
# 2      Quarter-finals
# 3         Group Stage
# 4         Group Stage
# ..                ...
# 62        Round of 16
# 63        Group Stage
# 64        Group Stage
# 65        Group Stage
# 66        Round of 16
#
# [67 rows x 16 columns]

# %%
spain_copy['year'].nunique()
# Out:
# 16

# %%
# Iterate through the matches and determine the stage reached by Spain
for index, match in spain_copy.iterrows():
    if match['home team name'] == 'Spain':
        stage_reached = match['stage'] if match['home team goals'] > match['away team goals'] else 'Eliminated'
    elif match['away team name'] == 'Spain':
        stage_reached = match['stage'] if match['away team goals'] > match['home team goals'] else 'Eliminated'
    spain_copy.at[index, 'stage_reached'] = stage_reached

# %%
display(spain_copy)

# %%
# Group by year and stage and count the number of matches
grouped = spain_copy.groupby(['year', 'stage_reached']).size().unstack(fill_value=0)

# Calculate the total matches played in each year
grouped['total_matches'] = grouped.sum(axis=1)

# Calculate the winning percentage for each stage in each year
grouped['winning_percentage'] = grouped['Round of 16'] / grouped['total_matches']

display(grouped)

# %%
# Group by year and stage and count the number of matches
grouped = spain_copy.groupby(['year', 'stage_reached']).size().unstack(fill_value=0)

# Calculate the total matches played in each year
grouped['total_matches'] = grouped.sum(axis=1)

# Calculate the winning percentage for each stage in each year
for stage in grouped.columns[:-1]:  # Exclude the 'total_matches' column
    grouped[f'{stage}_winning_percentage'] = grouped[stage] / grouped['total_matches']

display(grouped)
